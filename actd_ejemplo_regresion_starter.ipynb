# %%
import pandas as pd

# %%
data = pd.read_csv('data/advertising.csv', index_col=0)

# %%
data.shape
# Out:
# (200, 4)

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %% [markdown]
# - **TV**: gasto en publicidad en TV
# - **Radio**: gasto en publicidad en radio
# - **Newspaper**: gasto en publicidad en periódico
#
# Todos en miles de dólares
#
# - **Sales**: ventas del producto publicitado en miles de unidades

# %% [markdown]
# ### Estadísticas descriptivas

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# ### Incluir seaborn para Visualización

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# ### Histogramas por cada variable y dispersión entre variables

# %%
sns.pairplot(data,)

# %% [markdown]
# ### Matriz de correlación

# %%
import seaborn as sb
corr = data.corr()
sb.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <Axes: >

# %%
corrw = data.drop(['Sales'], axis=1).corrwith(data['Sales'])
sb.heatmap(pd.DataFrame(corrw), cmap="Blues", annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Diagramas de dispersión y tendencia entre variables de entrada y variable de respuesta

# %%
sns.pairplot(data, x_vars=['TV','Radio','Newspaper'], y_vars='Sales', height=7, aspect=0.7, kind='reg')

# %% [markdown]
# ### Modelo de regresión
#
# $y = \beta_0 + \beta_1 \times \text{TV} + \beta_2 \times \text{Radio} + \beta_3 \times \text{Newspaper}$

# %%
# nombres de características
features = ['TV', 'Radio', 'Newspaper']

# dataframe de características
X = data[features]

X.head()
# Out:
#       TV  Radio  Newspaper
# 1  230.1   37.8       69.2
# 2   44.5   39.3       45.1
# 3   17.2   45.9       69.3
# 4  151.5   41.3       58.5
# 5  180.8   10.8       58.4

# %%
X.shape
# Out:
# (200, 3)

# %%
# variable de respuesta
y = data['Sales']

y.head()
# Out:
# 1    22.1
# 2    10.4
# 3     9.3
# 4    18.5
# 5    12.9
# Name: Sales, dtype: float64

# %%
# tipos de X y y
print(type(X))
print(type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ### División entre entrenamiento y prueba

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# tamaños 
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (150, 3)
# (150,)
# (50, 3)
# (50,)

# %%
print(X.head())
print(X_train.head())
# Out:
#       TV  Radio  Newspaper
# 1  230.1   37.8       69.2
# 2   44.5   39.3       45.1
# 3   17.2   45.9       69.3
# 4  151.5   41.3       58.5
# 5  180.8   10.8       58.4
#         TV  Radio  Newspaper
# 99   289.7   42.3       51.2
# 124  123.1   34.6       12.4
# 120   19.4   16.0       22.3
# 54   182.6   46.2       58.7
# 34   265.6   20.0        0.3

# %%
# cambiando el tamaño del conjunto de prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.2)

# %%
# tamaños 
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (160, 3)
# (160,)
# (40, 3)
# (40,)

# %%
# sin reordenar los datos
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, shuffle=False)

# %%
print(X.head())
print(X_train.head())
# Out:
#       TV  Radio  Newspaper
# 1  230.1   37.8       69.2
# 2   44.5   39.3       45.1
# 3   17.2   45.9       69.3
# 4  151.5   41.3       58.5
# 5  180.8   10.8       58.4
#       TV  Radio  Newspaper
# 1  230.1   37.8       69.2
# 2   44.5   39.3       45.1
# 3   17.2   45.9       69.3
# 4  151.5   41.3       58.5
# 5  180.8   10.8       58.4

# %%
# tamaños 
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (150, 3)
# (150,)
# (50, 3)
# (50,)

# %%
# volviendo al caso en que cambia el tamaño del conjunto de prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# crear el objeto del modelo
linreg = LinearRegression()

# ajustar los parámetros del modelo usando los datos de entrenamiento
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# imprimir coeficientes
print(linreg.intercept_)
print(linreg.coef_)
# Out:
# 2.907947020816433
# [0.0468431  0.17854434 0.00258619]

# %%
# coeficientes con nombre de las características
list(zip(features, linreg.coef_))
# Out:
# [('TV', np.float64(0.04684310317699042)),
#  ('Radio', np.float64(0.17854434380887602)),
#  ('Newspaper', np.float64(0.0025861860939890013))]

# %% [markdown]
# ### Predicciones usando los datos de prueba

# %%
y_pred = linreg.predict(X_test)

# %% [markdown]
# ### Evaluar el modelo

# %% [markdown]
# **Error absoluto medio**:
#
# $$\text{MAE} = \frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# **Error cuadrado medio**:
# $$\text{MSE} = \frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **Raíz del Error cuadrado medio**:
# $$\text{RMSE} = \sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$

# %%
from sklearn import metrics

# %%
import numpy as np

# mean absolute error
MAE = metrics.mean_absolute_error(y_test, y_pred)

# mean squared error
MSE = metrics.mean_squared_error(y_test, y_pred)

# root mean squared error
RMSE = np.sqrt(MSE)

# %%
print("MAE: ", MAE)
print("MSE: ", MSE)
print("RMSE: ", RMSE)
# Out:
# MAE:  1.0402154012924718
# MSE:  1.9918855518287906
# RMSE:  1.4113417558581587

# %% [markdown]
# ### Selección de variables - Modelo con otro subconjunto de variables

# %%
featuresb = ['TV', 'Radio']

X = data[featuresb]
y = data.Sales

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

linreg.fit(X_train, y_train)

y_pred = linreg.predict(X_test)

MAE = metrics.mean_absolute_error(y_test, y_pred)
MSE = metrics.mean_squared_error(y_test, y_pred)
RMSE = np.sqrt(MSE)

print("MAE: ", MAE)
print("MSE: ", MSE)
print("RMSE: ", RMSE)
# Out:
# MAE:  1.0477590411212603
# MSE:  1.9262760418667428
# RMSE:  1.3879034699382888

# %% [markdown]
# ### Validación cruzada

# %%
from sklearn.model_selection import cross_val_score

# usar MSE - error cuadrático medio
scores = cross_val_score(linreg, X, y, cv=5, scoring='neg_mean_squared_error')
mse_scores = - scores
print(mse_scores)
# Out:
# [3.07164335 2.41053755 1.5737634  5.20917023 2.79308892]

# %%
# calcular RMSE
rmse_scores = np.sqrt(mse_scores)
print(rmse_scores)
# Out:
# [1.75261044 1.55259059 1.25449727 2.28236067 1.6712537 ]

# %%
# RMSE promedio a través de todos los grupos
print(rmse_scores.mean())
# Out:
# 1.7026625340333177

# %% [markdown]
# ## Ahora usando statsmodels

# %%
import statsmodels.api as sm

features = ['TV', 'Radio', 'Newspaper']

X = data[features]
y = data.Sales

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# agregar constante explíticamente
X_train = sm.add_constant(X_train)

# regresión usando mínimos cuadrados ordinarios (ordinary least squares - OLS) 
model = sm.OLS(y_train, X_train).fit()

# resumen de resultados
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.890
# Model:                            OLS   Adj. R-squared:                  0.888
# Method:                 Least Squares   F-statistic:                     395.0
# Date:                Thu, 22 Aug 2024   Prob (F-statistic):           7.84e-70
# Time:                        14:55:02   Log-Likelihood:                -297.38
# No. Observations:                 150   AIC:                             602.8
# Df Residuals:                     146   BIC:                             614.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.8770      0.368      7.822      0.000       2.150       3.604
# TV             0.0466      0.002     27.873      0.000       0.043       0.050
# Radio          0.1792      0.011     16.924      0.000       0.158       0.200
# Newspaper      0.0035      0.008      0.458      0.647      -0.011       0.018
# ==============================================================================
# Omnibus:                       41.940   Durbin-Watson:                   2.114
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               84.319
# Skew:                          -1.247   Prob(JB):                     4.90e-19
# Kurtosis:                       5.696   Cond. No.                         433.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### El segundo modelo, sin Newspaper

# %%
featuresb = ['TV', 'Radio']

X = data[featuresb]
y = data.Sales

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# agregar constante explíticamente
X_train = sm.add_constant(X_train)

# regresión usando mínimos cuadrados ordinarios (ordinary least squares - OLS) 
model = sm.OLS(y_train, X_train).fit()

# resumen de resultados
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.890
# Model:                            OLS   Adj. R-squared:                  0.889
# Method:                 Least Squares   F-statistic:                     595.6
# Date:                Thu, 22 Aug 2024   Prob (F-statistic):           3.15e-71
# Time:                        14:55:02   Log-Likelihood:                -297.48
# No. Observations:                 150   AIC:                             601.0
# Df Residuals:                     147   BIC:                             610.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9272      0.350      8.360      0.000       2.235       3.619
# TV             0.0466      0.002     28.005      0.000       0.043       0.050
# Radio          0.1812      0.010     18.878      0.000       0.162       0.200
# ==============================================================================
# Omnibus:                       42.606   Durbin-Watson:                   2.127
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               88.033
# Skew:                          -1.252   Prob(JB):                     7.65e-20
# Kurtosis:                       5.795   Cond. No.                         409.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Determinar la influencia de las observaciones

# %%
fig = sm.graphics.influence_plot(model, criterion="cooks")

# %% [markdown]
# ### Determinar puntos de alta influencia con distancia de Cook y umbral $4/n$

# %%
# disntacia de Cook
model_cooksd = model.get_influence().cooks_distance[0]

# get length of df to obtain n
n = X_train.shape[0]

# umbral
critical_d = 4/n
print('Umbral con distancia de Cook:', critical_d)

# puntos que podrían ser ourliers con alta influencia
out_d = model_cooksd > critical_d

print(X_train.index[out_d], "\n", model_cooksd[out_d])
# Out:
# Umbral con distancia de Cook: 0.02666666666666667
# Index([79, 6, 76, 3, 131, 127, 170, 132, 179, 26], dtype='int64')
#  [0.03046438 0.12569998 0.03345016 0.03192633 0.27702203 0.04896067
#  0.03165896 0.03577477 0.0810171  0.05155791]

# %%
X_train[out_d]
# Out:
#      const     TV  Radio
# 79     1.0    5.4   29.9
# 6      1.0    8.7   48.9
# 76     1.0   16.9   43.7
# 3      1.0   17.2   45.9
# 131    1.0    0.7   39.6
# 127    1.0    7.8   38.9
# 170    1.0  284.3   10.6
# 132    1.0  265.2    2.9
# 179    1.0  276.7    2.3
# 26     1.0  262.9    3.5

# %%
y_train[out_d]
# Out:
# 79      5.3
# 6       7.2
# 76      8.7
# 3       9.3
# 131     1.6
# 127     6.6
# 170    15.0
# 132    12.7
# 179    11.8
# 26     12.0
# Name: Sales, dtype: float64
